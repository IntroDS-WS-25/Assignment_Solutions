# %% [markdown]
# <div class='bar_title'></div>
#
# *Introduction to Data Science*
#
# # Assignment 4 - Plotting with Lets Plot Solutions
#
# Gunther Gust / Vanessa Haustein<br>
# Chair of Enterprise AI
#
# Winter Semester 25/26
#
# <img src='https://raw.githubusercontent.com/vhaus63/ids_data/main/d3.png?raw=true' style='width:20%; float:left;' />

# %%
import pandas as pd
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="nTNQHh"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("nTNQHh").appendChild(div);
#                     };
#                     var e = document.getElementById("nTNQHh");
#                     e.appendChild(script);
#                 })()
#             </script>

# %% [markdown]
# We will work with the `Cars` dataset from the Altair Viz module. It contains information on manufacturing and other attributes of cars.

# %%
df = pd.read_json('https://raw.githubusercontent.com/vhaus63/ids_data/refs/heads/main/cars.json')
df.head()
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    Horsepower  Weight_in_lbs  Acceleration        Year Origin
# 0       130.0           3504          12.0  1970-01-01    USA
# 1       165.0           3693          11.5  1970-01-01    USA
# 2       150.0           3436          11.0  1970-01-01    USA
# 3       150.0           3433          12.0  1970-01-01    USA
# 4       140.0           3449          10.5  1970-01-01    USA

# %% [markdown]
# ### Exercise 1: Visual Check of Correlation
#
# (a) We want to find out whether there is a linear correlation between the attributes `Horsepower` and `Miles_per_Gallon`. We will do this via a scatterplot that is supposed to look like this:
#
# <img src="https://raw.githubusercontent.com/vhaus63/ids_data/main/correlation_cars.png" style="width:60%;" />
#
# Recreate the plot.

# %%
(
    ggplot(df, aes(x='Horsepower', y='Miles_per_Gallon'))
    + geom_point(aes(color='Origin'))
    + geom_smooth(color='black')
    + ggtitle('Linear Correlation between Horsepower and Miles per Gallon')
    + ggsize(800, 500)
)
# Out:
#    <div id="T7KBpY"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("T7KBpY");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "Miles_per_Gallon":[18.0,15.0,18.0,16.0,17.0,15.0,14.0,14.0,14.0,15.0,null,null,null,null,null,15.0,14.0,null,15.0,14.0,24.0,22.0,18.0,21.0,27.0,26.0,25.0,24.0,25.0,26.0,21.0,10.0,10.0,11.0,9.0,27.0,28.0,25.0,25.0,null,19.0,16.0,17.0,19.0,18.0,14.0,14.0,14.0,14.0,12.0,13.0,13.0,18.0,22.0,19.0,18.0,23.0,28.0,30.0,30.0,31.0,35.0,27.0,26.0,24.0,25.0,23.0,20.0,21.0,13.0,14.0,15.0,14.0,17.0,11.0,13.0,12.0,13.0,19.0,15.0,13.0,13.0,14.0,18.0,22.0,21.0,26.0,22.0,28.0,23.0,28.0,27.0,13.0,14.0,13.0,14.0,15.0,12.0,13.0,13.0,14.0,13.0,12.0,13.0,18.0,16.0,18.0,18.0,23.0,26.0,11.0,12.0,13.0,12.0,18.0,20.0,21.0,22.0,18.0,19.0,21.0,26.0,15.0,16.0,29.0,24.0,20.0,19.0,15.0,24.0,20.0,11.0,20.0,21.0,19.0,15.0,31.0,26.0,32.0,25.0,16.0,16.0,18.0,16.0,13.0,14.0,14.0,14.0,29.0,26.0,26.0,31.0,32.0,28.0,24.0,26.0,24.0,26.0,31.0,19.0,18.0,15.0,15.0,16.0,15.0,16.0,14.0,17.0,16.0,15.0,18.0,21.0,20.0,13.0,29.0,23.0,20.0,23.0,24.0,25.0,24.0,18.0,29.0,19.0,23.0,23.0,22.0,25.0,33.0,28.0,25.0,25.0,26.0,27.0,17.5,16.0,15.5,14.5,22.0,22.0,24.0,22.5,29.0,24.5,29.0,33.0,20.0,18.0,18.5,17.5,29.5,32.0,28.0,26.5,20.0,13.0,19.0,19.0,16.5,16.5,13.0,13.0,13.0,31.5,30.0,36.0,25.5,33.5,17.5,17.0,15.5,15.0,17.5,20.5,19.0,18.5,16.0,15.5,15.5,16.0,29.0,24.5,26.0,25.5,30.5,33.5,30.0,30.5,22.0,21.5,21.5,43.1,36.1,32.8,39.4,36.1,19.9,19.4,20.2,19.2,20.5,20.2,25.1,20.5,19.4,20.6,20.8,18.6,18.1,19.2,17.7,18.1,17.5,30.0,27.5,27.2,30.9,21.1,23.2,23.8,23.9,20.3,17.0,21.6,16.2,31.5,29.5,21.5,19.8,22.3,20.2,20.6,17.0,17.6,16.5,18.2,16.9,15.5,19.2,18.5,31.9,34.1,35.7,27.4,25.4,23.0,27.2,23.9,34.2,34.5,31.8,37.3,28.4,28.8,26.8,33.5,41.5,38.1,32.1,37.2,28.0,26.4,24.3,19.1,34.3,29.8,31.3,37.0,32.2,46.6,27.9,40.8,44.3,43.4,36.4,30.0,44.6,40.9,33.8,29.8,32.7,23.7,35.0,23.6,32.4,27.2,26.6,25.8,23.5,30.0,39.1,39.0,35.1,32.3,37.0,37.7,34.1,34.7,34.4,29.9,33.0,34.5,33.7,32.4,32.9,31.6,28.1,null,30.7,25.4,24.2,22.4,26.6,20.2,17.6,28.0,27.0,34.0,31.0,29.0,27.0,24.0,23.0,36.0,37.0,31.0,38.0,36.0,36.0,36.0,34.0,38.0,32.0,38.0,25.0,38.0,26.0,22.0,32.0,36.0,27.0,27.0,44.0,32.0,28.0,31.0],
# "Horsepower":[130.0,165.0,150.0,150.0,140.0,198.0,220.0,215.0,225.0,190.0,115.0,165.0,153.0,175.0,175.0,170.0,160.0,140.0,150.0,225.0,95.0,95.0,97.0,85.0,88.0,46.0,87.0,90.0,95.0,113.0,90.0,215.0,200.0,210.0,193.0,88.0,90.0,95.0,null,48.0,100.0,105.0,100.0,88.0,100.0,165.0,175.0,153.0,150.0,180.0,170.0,175.0,110.0,72.0,100.0,88.0,86.0,90.0,70.0,76.0,65.0,69.0,60.0,70.0,95.0,80.0,54.0,90.0,86.0,165.0,175.0,150.0,153.0,150.0,208.0,155.0,160.0,190.0,97.0,150.0,130.0,140.0,150.0,112.0,76.0,87.0,69.0,86.0,92.0,97.0,80.0,88.0,175.0,150.0,145.0,137.0,150.0,198.0,150.0,158.0,150.0,215.0,225.0,175.0,105.0,100.0,100.0,88.0,95.0,46.0,150.0,167.0,170.0,180.0,100.0,88.0,72.0,94.0,90.0,85.0,107.0,90.0,145.0,230.0,49.0,75.0,91.0,112.0,150.0,110.0,122.0,180.0,95.0,null,100.0,100.0,67.0,80.0,65.0,75.0,100.0,110.0,105.0,140.0,150.0,150.0,140.0,150.0,83.0,67.0,78.0,52.0,61.0,75.0,75.0,75.0,97.0,93.0,67.0,95.0,105.0,72.0,72.0,170.0,145.0,150.0,148.0,110.0,105.0,110.0,95.0,110.0,110.0,129.0,75.0,83.0,100.0,78.0,96.0,71.0,97.0,97.0,70.0,90.0,95.0,88.0,98.0,115.0,53.0,86.0,81.0,92.0,79.0,83.0,140.0,150.0,120.0,152.0,100.0,105.0,81.0,90.0,52.0,60.0,70.0,53.0,100.0,78.0,110.0,95.0,71.0,70.0,75.0,72.0,102.0,150.0,88.0,108.0,120.0,180.0,145.0,130.0,150.0,68.0,80.0,58.0,96.0,70.0,145.0,110.0,145.0,130.0,110.0,105.0,100.0,98.0,180.0,170.0,190.0,149.0,78.0,88.0,75.0,89.0,63.0,83.0,67.0,78.0,97.0,110.0,110.0,48.0,66.0,52.0,70.0,60.0,110.0,140.0,139.0,105.0,95.0,85.0,88.0,100.0,90.0,105.0,85.0,110.0,120.0,145.0,165.0,139.0,140.0,68.0,95.0,97.0,75.0,95.0,105.0,85.0,97.0,103.0,125.0,115.0,133.0,71.0,68.0,115.0,85.0,88.0,90.0,110.0,130.0,129.0,138.0,135.0,155.0,142.0,125.0,150.0,71.0,65.0,80.0,80.0,77.0,125.0,71.0,90.0,70.0,70.0,65.0,69.0,90.0,115.0,115.0,90.0,76.0,60.0,70.0,65.0,90.0,88.0,90.0,90.0,78.0,90.0,75.0,92.0,75.0,65.0,105.0,65.0,48.0,48.0,67.0,67.0,67.0,null,67.0,62.0,132.0,100.0,88.0,null,72.0,84.0,84.0,92.0,110.0,84.0,58.0,64.0,60.0,67.0,65.0,62.0,68.0,63.0,65.0,65.0,74.0,null,75.0,75.0,100.0,74.0,80.0,110.0,76.0,116.0,120.0,110.0,105.0,88.0,85.0,88.0,88.0,88.0,85.0,84.0,90.0,92.0,null,74.0,68.0,68.0,63.0,70.0,88.0,75.0,70.0,67.0,67.0,67.0,110.0,85.0,92.0,112.0,96.0,84.0,90.0,86.0,52.0,84.0,79.0,82.0],
# "Origin":["USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","USA","USA","USA","USA","USA","USA","USA","USA","USA","Japan","USA","USA","USA","Japan","Europe","Europe","Europe","Europe","Europe","USA","USA","USA","USA","USA","Japan","USA","Japan","USA","Europe","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","Europe","Europe","Japan","Japan","Europe","USA","Japan","USA","Europe","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Japan","USA","USA","USA","USA","Europe","Europe","Europe","Europe","USA","Japan","Japan","USA","Japan","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","USA","USA","USA","USA","USA","Japan","USA","Japan","Japan","USA","USA","Europe","USA","USA","Europe","Europe","Europe","Europe","USA","Europe","Japan","USA","USA","USA","USA","USA","Japan","USA","Japan","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","Europe","Europe","Japan","Japan","USA","Europe","Europe","Japan","Japan","Europe","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Japan","USA","USA","USA","Japan","Europe","Japan","USA","Europe","USA","Europe","Europe","Europe","Europe","Japan","Europe","Europe","USA","USA","Europe","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","Japan","USA","USA","USA","USA","Europe","Japan","Japan","USA","Europe","USA","Europe","Japan","Europe","USA","USA","USA","USA","Japan","USA","Europe","USA","Japan","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","USA","Japan","USA","USA","USA","Japan","Europe","Japan","Europe","Japan","Europe","USA","Japan","Japan","Japan","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Japan","Japan","USA","Japan","USA","USA","Japan","Europe","Europe","Europe","Europe","Europe","Japan","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","Japan","USA","USA","Europe","USA","Europe","USA","USA","USA","Japan","Europe","USA","USA","USA","USA","Europe","Japan","USA","Japan","USA","USA","USA","USA","Europe","Japan","Japan","Japan","Japan","Japan","USA","Japan","Europe","Europe","Europe","Europe","Japan","Europe","Japan","Europe","Japan","Japan","Europe","USA","Japan","USA","USA","USA","USA","USA","Japan","USA","Japan","Japan","Japan","Japan","Japan","USA","USA","USA","Europe","Europe","Japan","Japan","Japan","Japan","Europe","Europe","Europe","Japan","Japan","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","Japan","Japan","USA","USA","Japan","Japan","Japan","Japan","Japan","Japan","USA","USA","USA","USA","Japan","USA","USA","USA","Europe","USA","USA","USA"]
# },
# "mapping":{
# "x":"Horsepower",
# "y":"Miles_per_Gallon"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Name"
# },{
# "type":"float",
# "column":"Miles_per_Gallon"
# },{
# "type":"int",
# "column":"Cylinders"
# },{
# "type":"float",
# "column":"Displacement"
# },{
# "type":"float",
# "column":"Horsepower"
# },{
# "type":"in

# %% [markdown]
# (b) In the plot before, we added a third dimension - the Origin of the cars - via the coloring of the points. Now we want to include the `Weight_in_lbs` attribute in our plot instead of the origin. Since this is not a categorical variable, we don't want to work with coloring (although we could, of course). We will vary the size of the scatter points depending on the weight variable. Change the plot accordingly.

# %%
(
    ggplot(df, aes(x='Horsepower', y='Miles_per_Gallon'))
    + geom_point(aes(size='Weight_in_lbs'), alpha=0.5)
    + ggtitle('Bubble Chart')
    + ggsize(800, 500)
)
# Out:
#    <div id="cGQRfy"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("cGQRfy");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "Miles_per_Gallon":[18.0,15.0,18.0,16.0,17.0,15.0,14.0,14.0,14.0,15.0,null,null,null,null,null,15.0,14.0,null,15.0,14.0,24.0,22.0,18.0,21.0,27.0,26.0,25.0,24.0,25.0,26.0,21.0,10.0,10.0,11.0,9.0,27.0,28.0,25.0,25.0,null,19.0,16.0,17.0,19.0,18.0,14.0,14.0,14.0,14.0,12.0,13.0,13.0,18.0,22.0,19.0,18.0,23.0,28.0,30.0,30.0,31.0,35.0,27.0,26.0,24.0,25.0,23.0,20.0,21.0,13.0,14.0,15.0,14.0,17.0,11.0,13.0,12.0,13.0,19.0,15.0,13.0,13.0,14.0,18.0,22.0,21.0,26.0,22.0,28.0,23.0,28.0,27.0,13.0,14.0,13.0,14.0,15.0,12.0,13.0,13.0,14.0,13.0,12.0,13.0,18.0,16.0,18.0,18.0,23.0,26.0,11.0,12.0,13.0,12.0,18.0,20.0,21.0,22.0,18.0,19.0,21.0,26.0,15.0,16.0,29.0,24.0,20.0,19.0,15.0,24.0,20.0,11.0,20.0,21.0,19.0,15.0,31.0,26.0,32.0,25.0,16.0,16.0,18.0,16.0,13.0,14.0,14.0,14.0,29.0,26.0,26.0,31.0,32.0,28.0,24.0,26.0,24.0,26.0,31.0,19.0,18.0,15.0,15.0,16.0,15.0,16.0,14.0,17.0,16.0,15.0,18.0,21.0,20.0,13.0,29.0,23.0,20.0,23.0,24.0,25.0,24.0,18.0,29.0,19.0,23.0,23.0,22.0,25.0,33.0,28.0,25.0,25.0,26.0,27.0,17.5,16.0,15.5,14.5,22.0,22.0,24.0,22.5,29.0,24.5,29.0,33.0,20.0,18.0,18.5,17.5,29.5,32.0,28.0,26.5,20.0,13.0,19.0,19.0,16.5,16.5,13.0,13.0,13.0,31.5,30.0,36.0,25.5,33.5,17.5,17.0,15.5,15.0,17.5,20.5,19.0,18.5,16.0,15.5,15.5,16.0,29.0,24.5,26.0,25.5,30.5,33.5,30.0,30.5,22.0,21.5,21.5,43.1,36.1,32.8,39.4,36.1,19.9,19.4,20.2,19.2,20.5,20.2,25.1,20.5,19.4,20.6,20.8,18.6,18.1,19.2,17.7,18.1,17.5,30.0,27.5,27.2,30.9,21.1,23.2,23.8,23.9,20.3,17.0,21.6,16.2,31.5,29.5,21.5,19.8,22.3,20.2,20.6,17.0,17.6,16.5,18.2,16.9,15.5,19.2,18.5,31.9,34.1,35.7,27.4,25.4,23.0,27.2,23.9,34.2,34.5,31.8,37.3,28.4,28.8,26.8,33.5,41.5,38.1,32.1,37.2,28.0,26.4,24.3,19.1,34.3,29.8,31.3,37.0,32.2,46.6,27.9,40.8,44.3,43.4,36.4,30.0,44.6,40.9,33.8,29.8,32.7,23.7,35.0,23.6,32.4,27.2,26.6,25.8,23.5,30.0,39.1,39.0,35.1,32.3,37.0,37.7,34.1,34.7,34.4,29.9,33.0,34.5,33.7,32.4,32.9,31.6,28.1,null,30.7,25.4,24.2,22.4,26.6,20.2,17.6,28.0,27.0,34.0,31.0,29.0,27.0,24.0,23.0,36.0,37.0,31.0,38.0,36.0,36.0,36.0,34.0,38.0,32.0,38.0,25.0,38.0,26.0,22.0,32.0,36.0,27.0,27.0,44.0,32.0,28.0,31.0],
# "Horsepower":[130.0,165.0,150.0,150.0,140.0,198.0,220.0,215.0,225.0,190.0,115.0,165.0,153.0,175.0,175.0,170.0,160.0,140.0,150.0,225.0,95.0,95.0,97.0,85.0,88.0,46.0,87.0,90.0,95.0,113.0,90.0,215.0,200.0,210.0,193.0,88.0,90.0,95.0,null,48.0,100.0,105.0,100.0,88.0,100.0,165.0,175.0,153.0,150.0,180.0,170.0,175.0,110.0,72.0,100.0,88.0,86.0,90.0,70.0,76.0,65.0,69.0,60.0,70.0,95.0,80.0,54.0,90.0,86.0,165.0,175.0,150.0,153.0,150.0,208.0,155.0,160.0,190.0,97.0,150.0,130.0,140.0,150.0,112.0,76.0,87.0,69.0,86.0,92.0,97.0,80.0,88.0,175.0,150.0,145.0,137.0,150.0,198.0,150.0,158.0,150.0,215.0,225.0,175.0,105.0,100.0,100.0,88.0,95.0,46.0,150.0,167.0,170.0,180.0,100.0,88.0,72.0,94.0,90.0,85.0,107.0,90.0,145.0,230.0,49.0,75.0,91.0,112.0,150.0,110.0,122.0,180.0,95.0,null,100.0,100.0,67.0,80.0,65.0,75.0,100.0,110.0,105.0,140.0,150.0,150.0,140.0,150.0,83.0,67.0,78.0,52.0,61.0,75.0,75.0,75.0,97.0,93.0,67.0,95.0,105.0,72.0,72.0,170.0,145.0,150.0,148.0,110.0,105.0,110.0,95.0,110.0,110.0,129.0,75.0,83.0,100.0,78.0,96.0,71.0,97.0,97.0,70.0,90.0,95.0,88.0,98.0,115.0,53.0,86.0,81.0,92.0,79.0,83.0,140.0,150.0,120.0,152.0,100.0,105.0,81.0,90.0,52.0,60.0,70.0,53.0,100.0,78.0,110.0,95.0,71.0,70.0,75.0,72.0,102.0,150.0,88.0,108.0,120.0,180.0,145.0,130.0,150.0,68.0,80.0,58.0,96.0,70.0,145.0,110.0,145.0,130.0,110.0,105.0,100.0,98.0,180.0,170.0,190.0,149.0,78.0,88.0,75.0,89.0,63.0,83.0,67.0,78.0,97.0,110.0,110.0,48.0,66.0,52.0,70.0,60.0,110.0,140.0,139.0,105.0,95.0,85.0,88.0,100.0,90.0,105.0,85.0,110.0,120.0,145.0,165.0,139.0,140.0,68.0,95.0,97.0,75.0,95.0,105.0,85.0,97.0,103.0,125.0,115.0,133.0,71.0,68.0,115.0,85.0,88.0,90.0,110.0,130.0,129.0,138.0,135.0,155.0,142.0,125.0,150.0,71.0,65.0,80.0,80.0,77.0,125.0,71.0,90.0,70.0,70.0,65.0,69.0,90.0,115.0,115.0,90.0,76.0,60.0,70.0,65.0,90.0,88.0,90.0,90.0,78.0,90.0,75.0,92.0,75.0,65.0,105.0,65.0,48.0,48.0,67.0,67.0,67.0,null,67.0,62.0,132.0,100.0,88.0,null,72.0,84.0,84.0,92.0,110.0,84.0,58.0,64.0,60.0,67.0,65.0,62.0,68.0,63.0,65.0,65.0,74.0,null,75.0,75.0,100.0,74.0,80.0,110.0,76.0,116.0,120.0,110.0,105.0,88.0,85.0,88.0,88.0,88.0,85.0,84.0,90.0,92.0,null,74.0,68.0,68.0,63.0,70.0,88.0,75.0,70.0,67.0,67.0,67.0,110.0,85.0,92.0,112.0,96.0,84.0,90.0,86.0,52.0,84.0,79.0,82.0],
# "Weight_in_lbs":[3504.0,3693.0,3436.0,3433.0,3449.0,4341.0,4354.0,4312.0,4425.0,3850.0,3090.0,4142.0,4034.0,4166.0,3850.0,3563.0,3609.0,3353.0,3761.0,3086.0,2372.0,2833.0,2774.0,2587.0,2130.0,1835.0,2672.0,2430.0,2375.0,2234.0,2648.0,4615.0,4376.0,4382.0,4732.0,2130.0,2264.0,2228.0,2046.0,1978.0,2634.0,3439.0,3329.0,3302.0,3288.0,4209.0,4464.0,4154.0,4096.0,4955.0,4746.0,5140.0,2962.0,2408.0,3282.0,3139.0,2220.0,2123.0,2074.0,2065.0,1773.0,1613.0,1834.0,1955.0,2278.0,2126.0,2254.0,2408.0,2226.0,4274.0,4385.0,4135.0,4129.0,3672.0,4633.0,4502.0,4456.0,4422.0,2330.0,3892.0,4098.0,4294.0,4077.0,2933.0,2511.0,2979.0,2189.0,2395.0,2288.0,2506.0,2164.0,2100.0,4100.0,3672.0,3988.0,4042.0,3777.0,4952.0,4464.0,4363.0,4237.0,4735.0,4951.0,3821.0,3121.0,3278.0,2945.0,3021.0,2904.0,1950.0,4997.0,4906.0,4654.0,4499.0,2789.0,2279.0,2401.0,2379.0,2124.0,2310.0,2472.0,2265.0,4082.0,4278.0,1867.0,2158.0,2582.0,2868.0,3399.0,2660.0,2807.0,3664.0,3102.0,2875.0,2901.0,3336.0,1950.0,2451.0,1836.0,2542.0,3781.0,3632.0,3613.0,4141.0,4699.0,4457.0,4638.0,4257.0,2219.0,1963.0,2300.0,1649.0,2003.0,2125.0,2108.0,2246.0,2489.0,2391.0,2000.0,3264.0,3459.0,3432.0,3158.0,4668.0,4440.0,4498.0,4657.0,3907.0,3897.0,3730.0,3785.0,3039.0,3221.0,3169.0,2171.0,2639.0,2914.0,2592.0,2702.0,2223.0,2545.0,2984.0,1937.0,3211.0,2694.0,2957.0,2945.0,2671.0,1795.0,2464.0,2220.0,2572.0,2255.0,2202.0,4215.0,4190.0,3962.0,4215.0,3233.0,3353.0,3012.0,3085.0,2035.0,2164.0,1937.0,1795.0,3651.0,3574.0,3645.0,3193.0,1825.0,1990.0,2155.0,2565.0,3150.0,3940.0,3270.0,2930.0,3820.0,4380.0,4055.0,3870.0,3755.0,2045.0,2155.0,1825.0,2300.0,1945.0,3880.0,4060.0,4140.0,4295.0,3520.0,3425.0,3630.0,3525.0,4220.0,4165.0,4325.0,4335.0,1940.0,2740.0,2265.0,2755.0,2051.0,2075.0,1985.0,2190.0,2815.0,2600.0,2720.0,1985.0,1800.0,1985.0,2070.0,1800.0,3365.0,3735.0,3570.0,3535.0,3155.0,2965.0,2720.0,3430.0,3210.0,3380.0,3070.0,3620.0,3410.0,3425.0,3445.0,3205.0,4080.0,2155.0,2560.0,2300.0,2230.0,2515.0,2745.0,2855.0,2405.0,2830.0,3140.0,2795.0,3410.0,1990.0,2135.0,3245.0,2990.0,2890.0,3265.0,3360.0,3840.0,3725.0,3955.0,3830.0,4360.0,4054.0,3605.0,3940.0,1925.0,1975.0,1915.0,2670.0,3530.0,3900.0,3190.0,3420.0,2200.0,2150.0,2020.0,2130.0,2670.0,2595.0,2700.0,2556.0,2144.0,1968.0,2120.0,2019.0,2678.0,2870.0,3003.0,3381.0,2188.0,2711.0,2542.0,2434.0,2265.0,2110.0,2800.0,2110.0,2085.0,2335.0,2950.0,3250.0,1850.0,1835.0,2145.0,1845.0,2910.0,2420.0,2500.0,2905.0,2290.0,2490.0,2635.0,2620.0,2725.0,2385.0,1755.0,1875.0,1760.0,2065.0,1975.0,2050.0,1985.0,2215.0,2045.0,2380.0,2190.0,2320.0,2210.0,2350.0,2615.0,2635.0,3230.0,2800.0,3160.0,2900.0,2930.0,3415.0,3725.0,3060.0,3465.0,2605.0,2640.0,2395.0,2575.0,2525.0,2735.0,2865.0,3035.0,1980.0,2025.0,1970.0,2125.0,2125.0,2160.0,2205.0,2245.0,1965.0,1965.0,1995.0,2945.0,3015.0,2585.0,2835.0,2665.0,2370.0,2950.0,2790.0,2130.0,2295.0,2625.0,2720.0]
# },
# "mapping":{
# "x":"Horsepower",
# "y":"Miles_per_Gallon"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Name"
# },{
# "type":"float",
# "column":"Miles_per_Gallon"
# },{
# "type":"int",
# "column":"Cylinders"
# },{
# "type":"float",
# "column":"Displacement"
# },{
# "type":"float",

# %% [markdown]
# (c) You can see that especially in the lower part of the plot it looks very crowded. It would be really nice to have a function to zoom into the plot interactively. Can you find a way to do that?

# %%
(
    ggplot(df, aes(x='Horsepower', y='Miles_per_Gallon'))
    + ggtb()
    + geom_point(aes(size='Weight_in_lbs'), alpha=0.5)
    + ggtitle('Bubble Chart')
    + ggsize(800, 500)
)
# Out:
#    <div id="tZspvF"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("tZspvF");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "Miles_per_Gallon":[18.0,15.0,18.0,16.0,17.0,15.0,14.0,14.0,14.0,15.0,null,null,null,null,null,15.0,14.0,null,15.0,14.0,24.0,22.0,18.0,21.0,27.0,26.0,25.0,24.0,25.0,26.0,21.0,10.0,10.0,11.0,9.0,27.0,28.0,25.0,25.0,null,19.0,16.0,17.0,19.0,18.0,14.0,14.0,14.0,14.0,12.0,13.0,13.0,18.0,22.0,19.0,18.0,23.0,28.0,30.0,30.0,31.0,35.0,27.0,26.0,24.0,25.0,23.0,20.0,21.0,13.0,14.0,15.0,14.0,17.0,11.0,13.0,12.0,13.0,19.0,15.0,13.0,13.0,14.0,18.0,22.0,21.0,26.0,22.0,28.0,23.0,28.0,27.0,13.0,14.0,13.0,14.0,15.0,12.0,13.0,13.0,14.0,13.0,12.0,13.0,18.0,16.0,18.0,18.0,23.0,26.0,11.0,12.0,13.0,12.0,18.0,20.0,21.0,22.0,18.0,19.0,21.0,26.0,15.0,16.0,29.0,24.0,20.0,19.0,15.0,24.0,20.0,11.0,20.0,21.0,19.0,15.0,31.0,26.0,32.0,25.0,16.0,16.0,18.0,16.0,13.0,14.0,14.0,14.0,29.0,26.0,26.0,31.0,32.0,28.0,24.0,26.0,24.0,26.0,31.0,19.0,18.0,15.0,15.0,16.0,15.0,16.0,14.0,17.0,16.0,15.0,18.0,21.0,20.0,13.0
.0,1937.0,1795.0,3651.0,3574.0,3645.0,3193.0,1825.0,1990.0,2155.0,2565.0,3150.0,3940.0,3270.0,2930.0,3820.0,4380.0,4055.0,3870.0,3755.0,2045.0,2155.0,1825.0,2300.0,1945.0,3880.0,4060.0,4140.0,4295.0,3520.0,3425.0,3630.0,3525.0,4220.0,4165.0,4325.0,4335.0,1940.0,2740.0,2265.0,2755.0,2051.0,2075.0,1985.0,2190.0,2815.0,2600.0,2720.0,1985.0,1800.0,1985.0,2070.0,1800.0,3365.0,3735.0,3570.0,3535.0,3155.0,2965.0,2720.0,3430.0,3210.0,3380.0,3070.0,3620.0,3410.0,3425.0,3445.0,3205.0,4080.0,2155.0,2560.0,2300.0,2230.0,2515.0,2745.0,2855.0,2405.0,2830.0,3140.0,2795.0,3410.0,1990.0,2135.0,3245.0,2990.0,2890.0,3265.0,3360.0,3840.0,3725.0,3955.0,3830.0,4360.0,4054.0,3605.0,3940.0,1925.0,1975.0,1915.0,2670.0,3530.0,3900.0,3190.0,3420.0,2200.0,2150.0,2020.0,2130.0,2670.0,2595.0,2700.0,2556.0,2144.0,1968.0,2120.0,2019.0,2678.0,2870.0,3003.0,3381.0,2188.0,2711.0,2542.0,2434.0,2265.0,2110.0,2800.0,2110.0,2085.0,2335.0,2950.0,3250.0,1850.0,1835.0,2145.0,1845.0,2910.0,2420.0,2500.0,2905.0,2290.0,2490.0,2635.0,2620.0,2725.0,2385.0,1755.0,1875.0,1760.0,2065.0,1975.0,2050.0,1985.0,2215.0,2045.0,2380.0,2190.0,2320.0,2210.0,2350.0,2615.0,2635.0,3230.0,2800.0,3160.0,2900.0,2930.0,3415.0,3725.0,3060.0,3465.0,2605.0,2640.0,2395.0,2575.0,2525.0,2735.0,2865.0,3035.0,1980.0,2025.0,1970.0,2125.0,2125.0,2160.0,2205.0,2245.0,1965.0,1965.0,1995.0,2945.0,3015.0,2585.0,2835.0,2665.0,2370.0,2950.0,2790.0,2130.0,2295.0,2625.0,2720.0]
# },
# "mapping":{
# "x":"Horsepower",
# "y":"Miles_per_Gallon"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Name"
# },{
# "type":"float",
# "column":"Miles_per_Gallon"
# },{
# "type":"int",
# "column":"Cylinders"
# },{
# "type":"float",
# "column":"Displacement"
# },{
# "type":"float",

# %% [markdown]
# ### Exercise 2:
# Find a good visualization for the interplay between Origin, Year and Horsepower.
#
# Before you start to plot, change the Year column. You may have noticed that here, every year is given by year-01-01. We will drop the month and the day since they contain no additional information and would otherwise be annoying in a plot legend.

# %%
df['Year'] = df['Year'].str.split('-', expand=True)[0]

# %%
df
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration  Year  Origin
# 0         130.0           3504          12.0  1970     USA
# 1         165.0           3693          11.5  1970     USA
# 2         150.0           3436          11.0  1970     USA
# 3         150.0           3433          12.0  1970     USA
# 4         140.0           3449          10.5  1970     USA
# ..          ...            ...           ...   ...     ...
# 401        86.0           2790          15.6  1982     USA
# 402        52.0           2130          24.6  1982  Europe
# 403        84.0           2295          11.6  1982     USA
# 404        79.0           2625          18.6  1982     USA
# 405        82.0           2720          19.4  1982     USA
#
# [406 rows x 9 columns]

# %%
(
    ggplot(df, aes(x='Year', y='Origin', fill='Horsepower'))
    + geom_tile()
    + scale_fill_gradient(low='yellow', high='blue')
    + ggtitle('Horsepower per Origin and Year')
)
# Out:
#    <div id="u1Tlf8"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("u1Tlf8");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "Horsepower":[130.0,165.0,150.0,150.0,140.0,198.0,220.0,215.0,225.0,190.0,115.0,165.0,153.0,175.0,175.0,170.0,160.0,140.0,150.0,225.0,95.0,95.0,97.0,85.0,88.0,46.0,87.0,90.0,95.0,113.0,90.0,215.0,200.0,210.0,193.0,88.0,90.0,95.0,null,48.0,100.0,105.0,100.0,88.0,100.0,165.0,175.0,153.0,150.0,180.0,170.0,175.0,110.0,72.0,100.0,88.0,86.0,90.0,70.0,76.0,65.0,69.0,60.0,70.0,95.0,80.0,54.0,90.0,86.0,165.0,175.0,150.0,153.0,150.0,208.0,155.0,160.0,190.0,97.0,150.0,130.0,140.0,150.0,112.0,76.0,87.0,69.0,86.0,92.0,97.0,80.0,88.0,175.0,150.0,145.0,137.0,150.0,198.0,150.0,158.0,150.0,215.0,225.0,175.0,105.0,100.0,100.0,88.0,95.0,46.0,150.0,167.0,170.0,180.0,100.0,88.0,72.0,94.0,90.0,85.0,107.0,90.0,145.0,230.0,49.0,75.0,91.0,112.0,150.0,110.0,122.0,180.0,95.0,null,100.0,100.0,67.0,80.0,65.0,75.0,100.0,110.0,105.0,140.0,150.0,150.0,140.0,150.0,83.0,67.0,78.0,52.0,61.0,75.0,75.0,75.0,97.0,93.0,67.0,95.0,105.0,72.0,72.0,170.0,145.0,150.0,148.0,110.0,105.0,110.0,95.0,110.0,110.0,129.0,75.0,83.0,100.0,78.0,96.0,71.0,97.0,97.0,70.0,90.0,95.0,88.0,98.0,115.0,53.0,86.0,81.0,92.0,79.0,83.0,140.0,150.0,120.0,152.0,100.0,105.0,81.0,90.0,52.0,60.0,70.0,53.0,100.0,78.0,110.0,95.0,71.0,70.0,75.0,72.0,102.0,150.0,88.0,108.0,120.0,180.0,145.0,130.0,150.0,68.0,80.0,58.0,96.0,70.0,145.0,110.0,145.0,130.0,110.0,105.0,100.0,98.0,180.0,170.0,190.0,149.0,78.0,88.0,75.0,89.0,63.0,83.0,67.0,78.0,97.0,110.0,110.0,48.0,66.0,52.0,70.0,60.0,110.0,140.0,139.0,105.0,95.0,85.0,88.0,100.0,90.0,105.0,85.0,110.0,120.0,145.0,165.0,139.0,140.0,68.0,95.0,97.0,75.0,95.0,105.0,85.0,97.0,103.0,125.0,115.0,133.0,71.0,68.0,115.0,85.0,88.0,90.0,110.0,130.0,129.0,138.0,135.0,155.0,142.0,125.0,150.0,71.0,65.0,80.0,80.0,77.0,125.0,71.0,90.0,70.0,70.0,65.0,69.0,90.0,115.0,115.0,90.0,76.0,60.0,70.0,65.0,90.0,88.0,90.0,90.0,78.0,90.0,75.0,92.0,75.0,65.0,105.0,65.0,48.0,48.0,67.0,67.0,67.0,null,67.0,62.0,132.0,100.0,88.0,null,72.0,84.0,84.0,92.0,110.0,84.0,58.0,64.0,60.0,67.0,65.0,62.0,68.0,63.0,65.0,65.0,74.0,null,75.0,75.0,100.0,74.0,80.0,110.0,76.0,116.0,120.0,110.0,105.0,88.0,85.0,88.0,88.0,88.0,85.0,84.0,90.0,92.0,null,74.0,68.0,68.0,63.0,70.0,88.0,75.0,70.0,67.0,67.0,67.0,110.0,85.0,92.0,112.0,96.0,84.0,90.0,86.0,52.0,84.0,79.0,82.0],
# "Year":["1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1970","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1971","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1972","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1973","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1974","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1975","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1976","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1977","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1978","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1979","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1980","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982","1982"],
# "Origin":["USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","USA","USA","USA","USA","USA","USA","USA","USA","USA","Japan","USA","USA","USA","Japan","Europe","Europe","Europe","Europe","Europe","USA","USA","USA","USA","USA","Japan","USA","Japan","USA","Europe","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","Europe","Europe","Japan","Japan","Europe","USA","Japan","USA","Europe","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Japan","USA","USA","USA","USA","Europe","Europe","Europe","Europe","USA","Japan","Japan","USA","Japan","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","USA","USA","USA","USA","USA","Japan","USA","Japan","Japan","USA","USA","Europe","USA","USA","Europe","Europe","Europe","Europe","USA","Europe","Japan","USA","USA","USA","USA","USA","Japan","USA","Japan","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","Europe","Europe","Japan","Japan","USA","Europe","Europe","Japan","Japan","Europe","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Japan","USA","USA","USA","Japan","Europe","Japan","USA","Europe","USA","Europe","Europe","Europe","Europe","Japan","Europe","Europe","USA","USA","Europe","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","Japan","USA","USA","USA","USA","Europe","Japan","Japan","USA","Europe","USA","Europe","Japan","Europe","USA","USA","USA","USA","Japan","USA","Europe","USA","Japan","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","USA","Japan","USA","USA","USA","Japan","Europe","Japan","Europe","Japan","Europe","USA","Japan","Japan","Japan","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Japan","Japan","USA","Japan","USA","USA","Japan","Europe","Europe","Europe","Europe","Europe","Japan","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","Japan","USA","USA","Europe","USA","Europe","USA","USA","USA","Japan","Europe","USA","USA","USA","USA","Europe","Japan","USA","Japan","USA","USA","USA","USA","Europe","Japan","Japan","Japan","Japan","Japan","USA","Japan","Europe","Europe","Europe","Europe","Japan","Europe"

# %% [markdown]
# ### Exercise 3: Dot Strip Plot
#
# Recreate this plot in order to evaluate the interplay between Horsepower and Cylinders for each Origin.
#
# <img src="https://raw.githubusercontent.com/vhaus63/ids_data/main/horsepower_cylinders.png" style="width:60%;" />

# %%
(
    ggplot(df, aes(x='Horsepower', y='Origin'))
    + geom_point(aes(color='Cylinders'), position=position_jitter(height=0.1))
    + ggsize(800, 500)
)
# Out:
#    <div id="BSd01e"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("BSd01e");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "Cylinders":[8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,4.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,4.0,6.0,6.0,6.0,4.0,4.0,4.0,4.0,4.0,4.0,6.0,8.0,8.0,8.0,8.0,4.0,4.0,4.0,4.0,4.0,6.0,6.0,6.0,6.0,6.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,6.0,4.0,6.0,6.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,3.0,8.0,8.0,8.0,8.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,6.0,6.0,6.0,6.0,6.0,4.0,8.0,8.0,8.0,8.0,6.0,4.0,4.0,4.0,3.0,4.0,6.0,4.0,8.0,8.0,4.0,4.0,4.0,4.0,8.0,4.0,6.0,8.0,6.0,6.0,6.0,6.0,4.0,4.0,4.0,4.0,6.0,6.0,6.0,8.0,8.0,8.0,8.0,8.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,6.0,6.0,6.0,6.0,8.0,8.0,8.0,8.0,6.0,6.0,6.0,6.0,6.0,8.0,8.0,4.0,4.0,6.0,4.0,4.0,4.0,4.0,6.0,4.0,6.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,8.0,8.0,8.0,8.0,6.0,6.0,6.0,6.0,4.0,4.0,4.0,4.0,6.0,6.0,6.0,6.0,4.0,4.0,4.0,4.0,4.0,8.0,4.0,6.0,6.0,8.0,8.0,8.0,8.0,4.0,4.0,4.0,4.0,4.0,8.0,8.0,8.0,8.0,6.0,6.0,6.0,6.0,8.0,8.0,8.0,8.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,6.0,4.0,3.0,4.0,4.0,4.0,4.0,4.0,8.0,8.0,8.0,6.0,6.0,6.0,4.0,6.0,6.0,6.0,6.0,6.0,6.0,8.0,6.0,8.0,8.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,5.0,6.0,4.0,6.0,4.0,4.0,6.0,6.0,4.0,6.0,6.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,4.0,4.0,4.0,4.0,5.0,8.0,4.0,8.0,4.0,4.0,4.0,4.0,4.0,6.0,6.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,6.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,5.0,4.0,4.0,4.0,4.0,4.0,6.0,3.0,4.0,4.0,4.0,4.0,4.0,4.0,6.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,6.0,6.0,6.0,6.0,8.0,6.0,6.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,6.0,6.0,4.0,6.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0
Japan","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","Europe","Japan","Japan","USA","USA","Japan","Japan","Japan","Japan","Japan","Japan","USA","USA","USA","USA","Japan","USA","USA","USA","Europe","USA","USA","USA"]
# },
# "mapping":{
# "x":"Horsepower",
# "y":"Origin"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Name"
# },{
# "type":"float",
# "column":"Miles_per_Gallon"
# },{
# "type":"int",
# "column":"Cylinders"
# },{
# "type":"float",
# "column":"Displacement"
# },{
# "type":"float",
# "column":"Horsepower"
# },{
# "type":"int",
# "column":"Weight_in_lbs"
# },{
# "type":"float",
# "column":"Acceleration"
# },{
# "type":"str",
# "column":"Year"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "ggsize":{
# "width":800.0,
# "height":500.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "color":"Cylinders"
# },
# "position":{
# "name":"jitter",
# "height":0.1
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# };
#                window.l

# %% [markdown]
# ### Exercise 4:

# %% [markdown]
# (a) We want to aggregate the data per year to see how parameters might have changed over time. Create a DataFrame called `df_agg` that contains the average horsepower and the average miles per gallon for each year.

# %%
df_agg = df.groupby('Year').agg({'Horsepower': 'mean', 'Miles_per_Gallon': 'mean'}).reset_index()
df_agg
# Out:
#     Year  Horsepower  Miles_per_Gallon
# 0   1970  148.857143         17.689655
# 1   1971  104.928571         21.250000
# 2   1972  120.178571         18.714286
# 3   1973  130.475000         17.100000
# 4   1974   94.230769         22.703704
# 5   1975  101.066667         20.266667
# 6   1976  101.117647         21.573529
# 7   1977  105.071429         23.375000
# 8   1978   99.694444         24.061111
# 9   1979  101.206897         25.093103
# 10  1980   77.481481         33.696552
# 11  1982   81.745763         31.045000

# %% [markdown]
# (b) Now you can recreate the following plot:
#
# <img src="https://raw.githubusercontent.com/vhaus63/ids_data/main/time_horsepower_cars.png" style="width:60%;" />

# %%
(
   ggplot(df_agg, aes('Horsepower', 'Miles_per_Gallon'))
   + geom_point(aes(color='Year'))
   + geom_segment(aes(xend=df_agg['Horsepower'].shift(-1),
                      yend=df_agg['Miles_per_Gallon'].shift(-1),
                      color='Year'),
                      arrow=arrow(type='closed', angle=40, length=10))
   + scale_color_gradient(low='lightblue', high='red', guide='none')
   + geom_text(aes(label='Year'), nudge_x=3.5, size=5)
)
# Out:
#    <div id="umIv6W"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("umIv6W");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "Year":["1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1982"],
# "Horsepower":[148.85714285714286,104.92857142857143,120.17857142857143,130.475,94.23076923076923,101.06666666666666,101.11764705882354,105.07142857142857,99.69444444444444,101.20689655172414,77.48148148148148,81.7457627118644],
# "Miles_per_Gallon":[17.689655172413794,21.25,18.714285714285715,17.1,22.703703703703702,20.266666666666666,21.573529411764707,23.375,24.061111111111114,25.093103448275862,33.69655172413793,31.045]
# },
# "mapping":{
# "x":"Horsepower",
# "y":"Miles_per_Gallon"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Year"
# },{
# "type":"float",
# "column":"Horsepower"
# },{
# "type":"float",
# "column":"Miles_per_Gallon"
# }]
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "guide":"none",
# "low":"lightblue",
# "high":"red",
# "scale_mapper_kind":"color_gradient"
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# "color":"Year"
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"segment",
# "mapping":{
# "xend":"xend",
# "yend":"yend",
# "color":"Year"
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "angle":40.0,
# "length":10.0,
# "type":"closed"
# },
# "data":{
# "xend":[104.92857142857143,120.17857142857143,130.475,94.23076923076923,101.06666666666666,101.11764705882354,105.07142857142857,99.69444444444444,101.20689655172414,77.48148148148148,81.7457627118644,null],
# "yend":[21.25,18.714285714285715,17.1,22.703703703703702,20.266666666666666,21.573529411764707,23.375,24.061111111111114,25.093103448275862,33.69655172413793,31.045,null]
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"Year"
# },
# "data_meta":{
# },
# "nudge_x":3.5,
# "size":5.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# (c) What insights does this plot provide?

# %% [markdown]
# - It visualizes the relationship between Horsepower and Miles per Gallon (MPG) over time, with points labeled by year
# - Higher horsepower correlates with lower MPG, indicating that cars with more powerful engines tend to be less fuel-efficient
# - Fuel efficiency seems to have improved over the years
# - Around 1980 there was a drastic incrcease in MPG with lower horsepower, indicating that in this time, fuel efficiency was highly prioritized in manufacturing cars

# %% [markdown]
# ### Exercise 5:
# In order to better understand the time-dependent evolution of efficiency (measured by MPG) in the manufactured cars, we want to create a statistical plot that contains for each Origin the mean and the 95% confidence intervall of the mean.
#
# Recreate this plot:
#
# <img src="https://raw.githubusercontent.com/vhaus63/ids_data/main/mpg_time_cars2.png" style="width:80%;" />

# %% [markdown]
# You can either create an aggregated table like we did above and add all the lines and fillings one by one or you can use the `stat_summary()` function. For upper and lower bound of the 95% confidence interval, use the formula
#
# `x.mean() +- 1.96 * x.std()/len(x)**0.5`.

# %%
(
    ggplot(df)
    # Adding mean line
    + stat_summary(aes(x='Year', y='Miles_per_Gallon', color='Origin'),
                 fun_y='mean', 
                 geom='line')
    # Adding confidence interval
    + stat_summary(aes(x='Year', y='Miles_per_Gallon', color='Origin', fill='Origin'),
                 fun_y='mean', 
                 fun_ymin=lambda x: x.mean() - 1.96 * x.std()/len(x)**0.5,
                 fun_ymax=lambda x: x.mean() + 1.96 * x.std()/len(x)**0.5,
                 geom='ribbon', 
                 alpha=0.3)
    + labs(y='Miles per Gallon', x='Year')
    + facet_wrap(facets='Origin', ncol=3, scales='fixed')
    + ggtitle('Miles per Gallon Over Years by Origin')
    + guides(color='none', fill='none')
)
# Out:
#    <div id="QZ3UQG"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("QZ3UQG");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Name"
# },{
# "type":"float",
# "column":"Miles_per_Gallon"
# },{
# "type":"int",
# "column":"Cylinders"
# },{
# "type":"float",
# "column":"Displacement"
# },{
# "type":"float",
# "column":"Horsepower"
# },{
# "type":"int",
# "column":"Weight_in_lbs"
# },{
# "type":"float",
# "column":"Acceleration"
# },{
# "type":"str",
# "column":"Year"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "guides":{
# "y":{
# "title":"Miles per Gallon"
# },
# "x":{
# "title":"Year"
# },
# "color":"none",
# "fill":"none"
# },
# "facet":{
# "name":"wrap",
# "facets":"Origin",
# "ncol":3.0,
# "scales":"fixed",
# "order":1.0,
# "dir":"h"
# },
# "ggtitle":{
# "text":"Miles per Gallon Over Years by Origin"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"line",
# "stat":"summary",
# "mapping":{
# "x":"Year",
# "y":"Miles_per_Gallon",
# "color":"Origin"
# },
# "data_meta":{
# "series_annotations":[{
# "column":"Year",
# "factor_levels":["1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1982"]
# },{
# "column":"Origin",
# "factor_levels":["USA","Europe","Japan"]
# }]
# },
# "fun_y":"mean",
# "data":{
# "..ymin..":[24.0,27.0,18.0,19.0,24.0,22.0,16.5,21.5,16.2,25.4,29.8,28.1,24.0,25.0,19.0,18.0,24.0,24.0,19.0,21.5,21.1,31.8,23.7,24.2,9.0,12.0,11.0,11.0,13.0,13.0,13.0,15.0,17.5,15.5,19.1,17.6],
# "..ymax..":[26.0,30.0,26.0,29.0,31.0,29.0,29.5,36.0,43.1,37.3,44.3,44.0,27.0,35.0,28.0,22.0,32.0,33.0,33.0,33.5,39.4,34.1,46.6,39.1,22.0,28.0,28.0,23.0,28.0,23.0,29.0,33.5,36.1,35.7,32.1,39.0],
# "Year":["1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1982","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1982","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1982"],
# "Miles_per_Gallon":[25.2,28.75,22.0,24.0,27.0,24.5,24.25,29.25,24.95,30.45,37.28888888888889,34.38333333333333,25.5,29.5,24.2,20.0,29.333333333333332,27.5,28.0,27.416666666666668,29.6875,32.95,35.400000000000006,33.78571428571429,15.272727272727273,18.1,16.27777777777778,15.03448275862069,18.333333333333332,17.55,19.431818181818183,20.72222222222222,21.772727272727277,23.47826086956522,25.914285714285715,28.693939393939395],
# "Origin":["Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Japan","Japan","Japan","Japan","Japan","Japan","Japan","Japan","Japan","Japan","Japan","Japan","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA"]
# }
# },{
# "geom":"ribbon",
# "stat":"summary",
# "mapping":{
# "x":"Year",
# "y":"Miles_per_Gallon",
# "color":"Origin",
# "fill":"Origin"
# },
# "data_meta":{
# "series_annotations":[{
# "column":"Year",
# "factor_levels":["1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1982"]
# },{
# "column":"Origin",
# "factor_levels":["USA","Europe","Japan"]
# }]
# },
# "fun_y":"mean",
# "fun_ymin":"<function <lambda> at 0x000001EFB2A880E0>",
# "fun_ymax":"<function <lambda> at 0x000001EFB2A89440>",
# "alpha":0.3,
# "data":{
# "..ymin..":[24.0,27.0,18.0,19.0,24.0,22.0,16.5,21.5,16.2,25.4,29.8,28.1,24.0,25.0,19.0,18.0,24.0,24.0,19.0,21.5,21.1,31.8,23.7,24.2,9.0,12.0,11.0,11.0,13.0,13.0,13.0,15.0,17.5,15.5,19.1,17.6],
# "..ymax..":[26.0,30.0,26.0,29.0,31.0,29.0,29.5,36.0,43.1,37.3,44.3,44.0,27.0,35.0,28.0,22.0,32.0,33.0,33.0,33.5,39.4,34.1,46.6,39.1,22.0,28.0,28.0,23.0,28.0,23.0,29.0,33.5,36.1,35.7,32.1,39.0],
# "Year":["1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1982","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1982","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1982"],
# "Miles_per_Gallon":[25.2,28.75,22.0,24.0,27.0,24.5,24.25,29.25,24.95,30.45,37.28888888888889,34.38333333333333,25.5,29.5,24.2,20.0,29.333333333333332,27.5,28.0,27.416666666666668,29.6875,32.95,35.400000000000006,33.78571428571429,15.272727272727273,18.1,16.27777777777778,15.03448275862069,18.333333333333332,17.55,19.431818181818183,20.72222222222222,21.772727272727277,23.47826086956522,25.914285714285715,28.693939393939395],
# "Origin":["Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Japan","Japan","Japan","Japan","Japan","Japan","Japan","Japan","Japan","Japan","Japan","Japan","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA","USA"]
# }
# }],
# "metainfo_list":[],
# "spec_id":"7"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
